# %% [markdown]
# # MNIST: multilayer perceptrons with PyTorch
#
# Multilayer perceptrons (MLPs) can be used for both regression and classification. In this notebook we train a classic MLP to recognize handwritten digits from the MNIST dataset, compare it with a model that uses dropout, and investigate the resulting classifiers.
#
# ## Learning objectives
#
# After working through this notebook, you should be able to:
#
# - prepare a built-in vision dataset with transformations and data loaders;
# - explain why a classification model returns logits rather than probabilities during training;
# - implement and train an MLP with and without dropout;
# - use validation evidence to select a model without consulting the test set;
# - interpret a confusion matrix and investigate sensitivity to initialization.

# %% [markdown]
# ## Configuration
#
# The complete experiment executes 100 epochs, including ten repeated training runs. That is computationally expensive. The default quick configuration preserves the workflow with shorter runs; set `FULL_EXPERIMENT = True` for the complete experiment.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import MNIST
from torchvision.transforms import v2

# %%
FULL_EXPERIMENT = False

BATCH_SIZE = 128
EPOCHS = 100 if FULL_EXPERIMENT else 5
SENSITIVITY_RUNS = 10 if FULL_EXPERIMENT else 3
SENSITIVITY_EPOCHS = 100 if FULL_EXPERIMENT else 5

SPLIT_SEED = 1234
MODEL_SEED = 4958
DATA_ORDER_SEED = 2718

DATA_DIR = Path.cwd() / "data"
MODEL_DIR = Path.cwd() / "models"

# %% [markdown]
# ## Reproducibility and device selection
#
# PyTorch uses its own random-number generator. A fixed seed makes the CPU run reproducible under the same software and hardware configuration. Exact results can still differ across devices or PyTorch versions because some accelerator operations are nondeterministic or use different numerical implementations.

# %%
def seed_everything(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


seed_everything(MODEL_SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data preparation
#
# ### Obtaining and transforming the dataset
#
# MNIST is provided by `torchvision.datasets`.A PyTorch `Dataset` retrieves individual image-label pairs. A `DataLoader` will later handle batching and shuffling.
#
# The transformation converts each image to a `float32` tensor and scales its pixel values from the integer range 0–255 to the floating-point range 0–1. Flattening is part of the model, so the dataset retains the meaningful image shape `[channel, height, width]`.

# %%
transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
])

# %%
full_train_dataset = MNIST(
    root=DATA_DIR,
    train=True,
    download=True,
    transform=transform,
)

test_dataset = MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=transform,
)

# %% [markdown]
# ### Validation set
#
# We split the 60,000 original training examples into 45,000 training and 15,000 validation examples. The test set remains untouched while models and training choices are being compared.

# %%
split_generator = torch.Generator().manual_seed(SPLIT_SEED)

train_dataset, validation_dataset = random_split(
    full_train_dataset,
    [45_000, 15_000],
    generator=split_generator,
)

len(train_dataset), len(validation_dataset), len(test_dataset)
# Out:
# (45000, 15000, 10000)

# %% [markdown]
# ### Data loaders
#
# The training loader shuffles examples at every epoch. Supplying its generator explicitly lets us reproduce the same sequence of shuffles when comparing models. Validation and test loaders do not shuffle because example order does not affect their metrics. When CUDA is used, pinned CPU memory and non-blocking device transfers can work together to make host-to-device copies asynchronous.

# %%
using_cuda = device.type == "cuda"


def make_train_loader(seed=DATA_ORDER_SEED):
    generator = torch.Generator().manual_seed(seed)
    return DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        generator=generator,
        num_workers=0,
        pin_memory=using_cuda,
    )


validation_loader = DataLoader(
    validation_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=using_cuda,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=using_cuda,
)

# %% [markdown]
# ### Verification
#
# Before training, inspect an image, its tensor properties, and its integer class label.

# %%
image, label = train_dataset[0]

print(f"shape: {tuple(image.shape)}")
print(f"dtype: {image.dtype}")
print(f"value range: [{image.min().item():.1f}, {image.max().item():.1f}]")
print(f"label: {label}")

plt.imshow(image.squeeze(0), cmap="gray")
plt.title(f"Label: {label}")
plt.axis("off")
plt.show()
# Out:
# shape: (1, 28, 28)
# dtype: torch.float32
# value range: [0.0, 1.0]
# label: 7

# %% [markdown]
# The target is an integer class index rather than a one-hot vector. This is exactly what `nn.CrossEntropyLoss` expects.
#
# ## Classic multilayer perceptron
#
# The network has 784 inputs (28 × 28 pixels), two hidden layers with 512 units and ReLU activations, and 10 output values—one per digit. `nn.Flatten` converts each image to 784 features inside the model.
#
# The final layer returns **logits**, not Softmax probabilities. `nn.CrossEntropyLoss` combines the numerically stable LogSoftmax and negative log-likelihood operations internally.

# %%
def make_mlp(dropout_probability=0.0):
    layers = [
        nn.Flatten(),
        nn.Linear(28 * 28, 512),
        nn.ReLU(),
    ]

    if dropout_probability > 0.0:
        layers.append(nn.Dropout(dropout_probability))

    layers.extend([
        nn.Linear(512, 512),
        nn.ReLU(),
    ])

    if dropout_probability > 0.0:
        layers.append(nn.Dropout(dropout_probability))

    layers.append(nn.Linear(512, 10))
    return nn.Sequential(*layers)

# %%
seed_everything(MODEL_SEED)
model = make_mlp().to(device)

model
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=512, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=512, out_features=512, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
parameter_count = sum(parameter.numel() for parameter in model.parameters())
print(f"Trainable parameters: {parameter_count:,}")
# Out:
# Trainable parameters: 669,706

# %% [markdown]
# ### Loss function and optimizer

# %% [markdown]
# The loss measures multiclass classification error, while stochastic gradient descent updates the weights. The learning rate `lr` is 0.01.

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ### Training and evaluation functions
#
# The PyTorch training loop has the following steps:
#
# 1. switch the model to training mode;
# 2. compute logits and loss for a batch;
# 3. compute gradients with backpropagation;
# 4. update parameters with the optimizer;
# 5. aggregate loss and accuracy over the epoch.
#
# Evaluation switches to evaluation mode—important for dropout—and disables gradient tracking.

# %%
def train_one_epoch(
    model,
    data_loader,
    loss_function,
    optimizer,
    device,
    non_blocking=False,
):
    model.train()
    total_loss = 0.0
    total_correct = 0
    total_examples = 0

    for features, targets in data_loader:
        features = features.to(device, non_blocking=non_blocking)
        targets = targets.to(device, non_blocking=non_blocking)

        optimizer.zero_grad(set_to_none=True)
        logits = model(features)
        loss = loss_function(logits, targets)
        loss.backward()
        optimizer.step()

        batch_size = targets.size(0)
        total_loss += loss.item() * batch_size
        total_correct += (logits.argmax(dim=1) == targets).sum().item()
        total_examples += batch_size

    return {
        "loss": total_loss / total_examples,
        "accuracy": total_correct / total_examples,
    }

# %%
@torch.inference_mode()
def evaluate(
    model,
    data_loader,
    loss_function,
    device,
    non_blocking=False,
):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_examples = 0

    for features, targets in data_loader:
        features = features.to(device, non_blocking=non_blocking)
        targets = targets.to(device, non_blocking=non_blocking)

        logits = model(features)
        loss = loss_function(logits, targets)

        batch_size = targets.size(0)
        total_loss += loss.item() * batch_size
        total_correct += (logits.argmax(dim=1) == targets).sum().item()
        total_examples += batch_size

    return {
        "loss": total_loss / total_examples,
        "accuracy": total_correct / total_examples,
    }

# %%
def fit(
    model,
    train_loader,
    validation_loader,
    loss_function,
    optimizer,
    epochs,
    device,
    non_blocking=False,
    verbose=True,
):
    history = {
        "loss": [],
        "accuracy": [],
        "val_loss": [],
        "val_accuracy": [],
    }

    for epoch in range(1, epochs + 1):
        train_metrics = train_one_epoch(
            model,
            train_loader,
            loss_function,
            optimizer,
            device,
            non_blocking,
        )
        validation_metrics = evaluate(
            model,
            validation_loader,
            loss_function,
            device,
            non_blocking,
        )

        history["loss"].append(train_metrics["loss"])
        history["accuracy"].append(train_metrics["accuracy"])
        history["val_loss"].append(validation_metrics["loss"])
        history["val_accuracy"].append(validation_metrics["accuracy"])

        if verbose:
            print(
                f"Epoch {epoch:3d}/{epochs}: "
                f"loss={train_metrics['loss']:.4f}, "
                f"accuracy={train_metrics['accuracy']:.4f}, "
                f"val_loss={validation_metrics['loss']:.4f}, "
                f"val_accuracy={validation_metrics['accuracy']:.4f}"
            )

    return history

# %% [markdown]
# ### Training

# %%
train_loader = make_train_loader()

model_history = fit(
    model=model,
    train_loader=train_loader,
    validation_loader=validation_loader,
    loss_function=loss_function,
    optimizer=optimizer,
    epochs=EPOCHS,
    device=device,
    non_blocking=using_cuda,
)
# Out:
# Epoch   1/100: loss=2.1722, accuracy=0.4424, val_loss=1.9289, val_accuracy=0.6621
# Epoch   2/100: loss=1.3893, accuracy=0.7416, val_loss=0.9133, val_accuracy=0.7975
# Epoch   3/100: loss=0.7137, accuracy=0.8292, val_loss=0.5937, val_accuracy=0.8432
# Epoch   4/100: loss=0.5221, accuracy=0.8638, val_loss=0.4826, val_accuracy=0.8691
# Epoch   5/100: loss=0.4422, accuracy=0.8800, val_loss=0.4279, val_accuracy=0.8818
# Epoch   6/100: loss=0.3987, accuracy=0.8896, val_loss=0.3954, val_accuracy=0.8890
# Epoch   7/100: loss=0.3702, accuracy=0.8958, val_loss=0.3740, val_accuracy=0.8932
# Epoch   8/100: loss=0.3496, accuracy=0.9006, val_loss=0.3569, val_accuracy=0.8985
# Epoch   9/100: loss=0.3333, accuracy=0.9045, val_loss=0.3453, val_accuracy=0.9014
# Epoch  10/100: loss=0.3201, accuracy=0.9076, val_loss=0.3337, val_accuracy=0.9037
# Epoch  11/100: loss=0.3085, accuracy=0.9118, val_loss=0.3225, val_accuracy=0.9080
# Epoch  12/100: loss=0.2979, accuracy=0.9151, val_loss=0.3128, val_accuracy=0.9093
# Epoch  13/100: loss=0.2882, accuracy=0.9168, val_loss=0.3049, val_accuracy=0.9129
# Epoch  14/100: loss=0.2795, accuracy=0.9190, val_loss=0.2962, val_accuracy=0.9139
# Epoch  15/100: loss=0.2713, accuracy=0.9219, val_loss=0.2885, val_accuracy=0.9166
# Epoch  16/100: loss=0.2639, accuracy=0.9243, val_loss=0.2811, val_accuracy=0.9187
# Epoch  17/100: loss=0.2563, accuracy=0.9265, val_loss=0.2750, val_accuracy=0.9206
# Epoch  18/100: loss=0.2494, accuracy=0.9284, val_loss=0.2688, val_accuracy=0.9223
# Epoch  19/100: loss=0.2430, accuracy=0.9305, val_loss=0.2640, val_accuracy=0.9233
# Epoch  20/100: loss=0.2365, accuracy=0.9319, val_loss=0.2565, val_accuracy=0.9257
# Epoch  21/100: loss=0.2306, accuracy=0.9336, val_loss=0.2523, val_accuracy=0.9275
# Epoch  22/100: loss=0.2248, accuracy=0.9358, val_loss=0.2467, val_accuracy=0.9293
# Epoch  23/100: loss=0.2193, accuracy=0.9370, val_loss=0.2409, val_accuracy=0.9307
# Epoch  24/100: loss=0.2138, accuracy=0.9385, val_loss=0.2367, val_accuracy=0.9328
# Epoch  25/100: loss=0.2086, accuracy=0.9407, val_loss=0.2319, val_accuracy=0.9335
# Epoch  26/100: loss=0.2035, accuracy=0.9423, val_loss=0.2274, val_accuracy=0.9353
# Epoch  27/100: loss=0.1988, accuracy=0.9434, val_loss=0.2245, val_accuracy=0.9364
# Epoch  28/100: loss=0.1941, accuracy=0.9451, val_loss=0.2192, val_accuracy=0.9374
# Epoch  29/100: loss=0.1896, accuracy=0.9462, val_loss=0.2144, val_accuracy=0.9391
# Epoch  30/100: loss=0.1855, accuracy=0.9473, val_loss=0.2116, val_accuracy=0.9391
# Epoch  31/100: loss=0.1811, accuracy=0.9482, val_loss=0.2066, val_accuracy=0.9413
# Epoch  32/100: loss=0.1769, accuracy=0.9495, val_loss=0.2055, val_accuracy=0.9419
# Epoch  33/100: loss=0.1733, accuracy=0.9502, val_loss=0.2009, val_accuracy=0.9430
# Epoch  34/100: loss=0.1695, accuracy=0.9515, val_loss=0.1967, val_accuracy=0.9437
# Epoch  35/100: loss=0.1659, accuracy=0.9522, val_loss=0.1948, val_accuracy=0.9442
# Epoch  36/100: loss=0.1621, accuracy=0.9538, val_loss=0.1899, val_accuracy=0.9453
# Epoch  37/100: loss=0.1588, accuracy=0.9547, val_loss=0.1867, val_accuracy=0.9470
# Epoch  38/100: loss=0.1555, accuracy=0.9557, val_loss=0.1833, val_accuracy=0.9468
# Epoch  39/100: loss=0.1520, accuracy=0.9569, val_loss=0.1827, val_accuracy=0.9479
# Epoch  40/100: loss=0.1491, accuracy=0.9578, val_loss=0.1779, val_accuracy=0.9483
# Epoch  57/100: loss=0.1077, accuracy=0.9697, val_loss=0.1428, val_accuracy=0.9580
# Epoch  58/100: loss=0.1058, accuracy=0.9703, val_loss=0.1424, val_accuracy=0.9584
# Epoch  59/100: loss=0.1040, accuracy=0.9709, val_loss=0.1403, val_accuracy=0.9593
# Epoch  60/100: loss=0.1021, accuracy=0.9715, val_loss=0.1386, val_accuracy=0.9601
# Epoch  61/100: loss=0.1004, accuracy=0.9721, val_loss=0.1373, val_accuracy=0.9599
# Epoch  62/100: loss=0.0987, accuracy=0.9729, val_loss=0.1352, val_accuracy=0.9605
# Epoch  63/100: loss=0.0970, accuracy=0.9734, val_loss=0.1343, val_accuracy=0.9612
# Epoch  64/100: loss=0.0953, accuracy=0.9735, val_loss=0.1329, val_accuracy=0.9612
# Epoch  65/100: loss=0.0936, accuracy=0.9738, val_loss=0.1336, val_accuracy=0.9617
# Epoch  66/100: loss=0.0921, accuracy=0.9745, val_loss=0.1311, val_accuracy=0.9618
# Epoch  67/100: loss=0.0908, accuracy=0.9748, val_loss=0.1289, val_accuracy=0.9627
# Epoch  68/100: loss=0.0892, accuracy=0.9754, val_loss=0.1287, val_accuracy=0.9628
# Epoch  69/100: loss=0.0875, accuracy=0.9758, val_loss=0.1269, val_accuracy=0.9631
# Epoch  70/100: loss=0.0862, accuracy=0.9758, val_loss=0.1268, val_accuracy=0.9624
# Epoch  71/100: loss=0.0848, accuracy=0.9761, val_loss=0.1253, val_accuracy=0.9643
# Epoch  72/100: loss=0.0835, accuracy=0.9771, val_loss=0.1238, val_accuracy=0.9635
# Epoch  73/100: loss=0.0820, accuracy=0.9773, val_loss=0.1240, val_accuracy=0.9658
# Epoch  74/100: loss=0.0807, accuracy=0.9775, val_loss=0.1221, val_accuracy=0.9641
# Epoch  75/100: loss=0.0796, accuracy=0.9782, val_loss=0.1206, val_accuracy=0.9651
# Epoch  76/100: loss=0.0782, accuracy=0.9785, val_loss=0.1198, val_accuracy=0.9659
# Epoch  77/100: loss=0.0769, accuracy=0.9786, val_loss=0.1191, val_accuracy=0.9656
# Epoch  78/100: loss=0.0758, accuracy=0.9790, val_loss=0.1182, val_accuracy=0.9663
# Epoch  79/100: loss=0.0746, accuracy=0.9796, val_loss=0.1172, val_accuracy=0.9666
# Epoch  80/100: loss=0.0733, accuracy=0.9800, val_loss=0.1156, val_accuracy=0.9665
# Epoch  81/100: loss=0.0721, accuracy=0.9802, val_loss=0.1157, val_accuracy=0.9665
# Epoch  82/100: loss=0.0710, accuracy=0.9805, val_loss=0.1151, val_accuracy=0.9667
# Epoch  83/100: loss=0.0699, accuracy=0.9810, val_loss=0.1136, val_accuracy=0.9669
# Epoch  84/100: loss=0.0689, accuracy=0.9815, val_loss=0.1138, val_accuracy=0.9669
# Epoch  85/100: loss=0.0679, accuracy=0.9815, val_loss=0.1124, val_accuracy=0.9676
# Epoch  86/100: loss=0.0667, accuracy=0.9819, val_loss=0.1119, val_accuracy=0.9669
# Epoch  87/100: loss=0.0657, accuracy=0.9822, val_loss=0.1108, val_accuracy=0.9675
# Epoch  88/100: loss=0.0647, accuracy=0.9825, val_loss=0.1102, val_accuracy=0.9679
# Epoch  89/100: loss=0.0638, accuracy=0.9826, val_loss=0.1100, val_accuracy=0.9673
# Epoch  90/100: loss=0.0628, accuracy=0.9832, val_loss=0.1094, val_accuracy=0.9681
# Epoch  91/100: loss=0.0619, accuracy=0.9833, val_loss=0.1086, val_accuracy=0.9682
# Epoch  92/100: loss=0.0609, accuracy=0.9836, val_loss=0.1076, val_accuracy=0.9683
# Epoch  93/100: loss=0.0600, accuracy=0.9843, val_loss=0.1067, val_accuracy=0.9679
# Epoch  94/100: loss=0.0591, accuracy=0.9840, val_loss=0.1067, val_accuracy=0.9689
# Epoch  95/100: loss=0.0581, accuracy=0.9846, val_loss=0.1064, val_accuracy=0.9687
# Epoch  96/100: loss=0.0573, accuracy=0.9847, val_loss=0.1060, val_accuracy=0.9681
# Epoch  97/100: loss=0.0564, accuracy=0.9847, val_loss=0.1056, val_accuracy=0.9689
# Epoch  98/100: loss=0.0557, accuracy=0.9851, val_loss=0.1051, val_accuracy=0.9688
# Epoch  99/100: loss=0.0547, accuracy=0.9856, val_loss=0.1040, val_accuracy=0.9693
# Epoch 100/100: loss=0.0540, accuracy=0.9858, val_loss=0.1034, val_accuracy=0.9687

# %% [markdown]
# Plot the history of the training process. Comparing training and validation curves helps diagnose underfitting and overfitting.

# %%
def plot_history(history):
    epochs = np.arange(1, len(history["loss"]) + 1)

    figure, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(epochs, history["loss"], label="Training")
    axes[0].plot(epochs, history["val_loss"], label="Validation")
    axes[0].set(xlabel="Epoch", ylabel="Loss")
    axes[0].legend()

    axes[1].plot(epochs, history["accuracy"], label="Training")
    axes[1].plot(epochs, history["val_accuracy"], label="Validation")
    axes[1].set(xlabel="Epoch", ylabel="Accuracy")
    axes[1].legend(loc="lower right")

    figure.tight_layout()


plot_history(model_history)

# %% [markdown]
# Compare performance on the training and validation sets. These are the development results used to diagnose and select models. The test set remains untouched until every model choice has been frozen.

# %%
def evaluate_development_sets(
    model,
    device,
    pin_memory=False,
    non_blocking=False,
):
    loaders = {
        "train": DataLoader(
            train_dataset,
            batch_size=BATCH_SIZE,
            shuffle=False,
            num_workers=0,
            pin_memory=pin_memory,
        ),
        "validation": validation_loader,
    }

    results = {}
    for name, data_loader in loaders.items():
        results[name] = evaluate(
            model,
            data_loader,
            loss_function,
            device,
            non_blocking,
        )
        metrics = results[name]
        print(
            f"{name:10s}: loss={metrics['loss']:.4f}, "
            f"accuracy={metrics['accuracy']:.4f}"
        )

    return results


model_development_results = evaluate_development_sets(
    model,
    device,
    pin_memory=using_cuda,
    non_blocking=using_cuda,
)
# Out:
# train     : loss=0.0526, accuracy=0.9859
# validation: loss=0.1034, accuracy=0.9687

# %% [markdown]
# ### Save and reload the model
#
# Saving a `state_dict` stores learned parameters without serializing arbitrary Python objects. To reload it, recreate the architecture and then load the weights.

# %%
MODEL_DIR.mkdir(parents=True, exist_ok=True)
model_path = MODEL_DIR / "mnist_mlp.pt"

torch.save(model.state_dict(), model_path)
print(f"Saved weights to {model_path}")
# Out:
# Saved weights to /home/gjb/Projects/Machine-learning-with-Python/source-code/pytorch/models/mnist_mlp.pt

# %%
reloaded_model = make_mlp().to(device)
reloaded_model.load_state_dict(
    torch.load(model_path, map_location=device, weights_only=True)
)

reloaded_validation_metrics = evaluate(
    reloaded_model,
    validation_loader,
    loss_function,
    device,
    non_blocking=using_cuda,
)
reloaded_validation_metrics
# Out:
# {'loss': 0.10344051860968272, 'accuracy': 0.9686666666666667}

# %% [markdown]
# ## Dropout layers
#
# Dropout randomly sets some activations to zero during training, discouraging the network from relying too strongly on particular paths. It is disabled automatically in evaluation mode.
#
# Before running the cell, predict how dropout will affect:
#
# - training loss and accuracy;
# - the gap between training and validation performance;
# - test performance.
#
# We reset both the model seed and data-loader seed so that the comparison changes the architecture while keeping initialization and batch order as comparable as possible.

# %%
seed_everything(MODEL_SEED)
dropout_model = make_mlp(dropout_probability=0.2).to(device)
dropout_optimizer = torch.optim.SGD(dropout_model.parameters(), lr=0.01)
dropout_train_loader = make_train_loader(DATA_ORDER_SEED)

dropout_model
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=512, bias=True)
#   (2): ReLU()
#   (3): Dropout(p=0.2, inplace=False)
#   (4): Linear(in_features=512, out_features=512, bias=True)
#   (5): ReLU()
#   (6): Dropout(p=0.2, inplace=False)
#   (7): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
dropout_model_history = fit(
    model=dropout_model,
    train_loader=dropout_train_loader,
    validation_loader=validation_loader,
    loss_function=loss_function,
    optimizer=dropout_optimizer,
    epochs=EPOCHS,
    device=device,
    non_blocking=using_cuda,
)
# Out:
# Epoch   1/100: loss=2.1879, accuracy=0.3948, val_loss=1.9631, val_accuracy=0.6483
# Epoch   2/100: loss=1.4723, accuracy=0.7013, val_loss=0.9565, val_accuracy=0.7885
# Epoch   3/100: loss=0.7854, accuracy=0.7976, val_loss=0.6125, val_accuracy=0.8391
# Epoch   4/100: loss=0.5830, accuracy=0.8378, val_loss=0.4949, val_accuracy=0.8659
# Epoch   5/100: loss=0.4965, accuracy=0.8589, val_loss=0.4372, val_accuracy=0.8804
# Epoch   6/100: loss=0.4471, accuracy=0.8731, val_loss=0.4019, val_accuracy=0.8867
# Epoch   7/100: loss=0.4142, accuracy=0.8800, val_loss=0.3795, val_accuracy=0.8904
# Epoch   8/100: loss=0.3894, accuracy=0.8876, val_loss=0.3594, val_accuracy=0.8983
# Epoch   9/100: loss=0.3706, accuracy=0.8929, val_loss=0.3461, val_accuracy=0.9013
# Epoch  10/100: loss=0.3551, accuracy=0.8976, val_loss=0.3319, val_accuracy=0.9047
# Epoch  11/100: loss=0.3416, accuracy=0.9010, val_loss=0.3203, val_accuracy=0.9076
# Epoch  12/100: loss=0.3277, accuracy=0.9054, val_loss=0.3093, val_accuracy=0.9109
# Epoch  13/100: loss=0.3160, accuracy=0.9083, val_loss=0.3007, val_accuracy=0.9135
# Epoch  14/100: loss=0.3068, accuracy=0.9105, val_loss=0.2905, val_accuracy=0.9157
# Epoch  15/100: loss=0.2938, accuracy=0.9145, val_loss=0.2822, val_accuracy=0.9180
# Epoch  16/100: loss=0.2848, accuracy=0.9170, val_loss=0.2744, val_accuracy=0.9206
# Epoch  17/100: loss=0.2767, accuracy=0.9203, val_loss=0.2669, val_accuracy=0.9227
# Epoch  18/100: loss=0.2676, accuracy=0.9224, val_loss=0.2594, val_accuracy=0.9246
# Epoch  19/100: loss=0.2597, accuracy=0.9244, val_loss=0.2535, val_accuracy=0.9262
# Epoch  20/100: loss=0.2535, accuracy=0.9273, val_loss=0.2456, val_accuracy=0.9292
# Epoch  21/100: loss=0.2460, accuracy=0.9280, val_loss=0.2397, val_accuracy=0.9312
# Epoch  22/100: loss=0.2376, accuracy=0.9318, val_loss=0.2344, val_accuracy=0.9330
# Epoch  23/100: loss=0.2343, accuracy=0.9320, val_loss=0.2285, val_accuracy=0.9345
# Epoch  24/100: loss=0.2263, accuracy=0.9344, val_loss=0.2234, val_accuracy=0.9365
# Epoch  25/100: loss=0.2193, accuracy=0.9360, val_loss=0.2184, val_accuracy=0.9377
# Epoch  26/100: loss=0.2145, accuracy=0.9385, val_loss=0.2131, val_accuracy=0.9390
# Epoch  27/100: loss=0.2095, accuracy=0.9402, val_loss=0.2088, val_accuracy=0.9395
# Epoch  28/100: loss=0.2045, accuracy=0.9405, val_loss=0.2045, val_accuracy=0.9409
# Epoch  29/100: loss=0.1990, accuracy=0.9423, val_loss=0.2000, val_accuracy=0.9426
# Epoch  30/100: loss=0.1949, accuracy=0.9424, val_loss=0.1968, val_accuracy=0.9429
# Epoch  31/100: loss=0.1909, accuracy=0.9444, val_loss=0.1921, val_accuracy=0.9441
# Epoch  32/100: loss=0.1858, accuracy=0.9452, val_loss=0.1896, val_accuracy=0.9447
# Epoch  33/100: loss=0.1807, accuracy=0.9474, val_loss=0.1857, val_accuracy=0.9454
# Epoch  34/100: loss=0.1765, accuracy=0.9490, val_loss=0.1821, val_accuracy=0.9467
# Epoch  35/100: loss=0.1728, accuracy=0.9488, val_loss=0.1792, val_accuracy=0.9468
# Epoch  36/100: loss=0.1706, accuracy=0.9502, val_loss=0.1754, val_accuracy=0.9486
# Epoch  37/100: loss=0.1665, accuracy=0.9505, val_loss=0.1723, val_accuracy=0.9498
# Epoch  38/100: loss=0.1637, accuracy=0.9524, val_loss=0.1693, val_accuracy=0.9504
# Epoch  39/100: loss=0.1594, accuracy=0.9531, val_loss=0.1680, val_accuracy=0.9509
# Epoch  40/100: loss=0.1580, accuracy=0.9540, val_loss=0.1641, val_accuracy=0.9511
# Epoch  41/100: loss=0.1550, accuracy=0.9555, val_loss=0.1621, val_accuracy=0.9519
# Epoch  42/100: loss=0.1514, accuracy=0.9554, val_loss=0.1592, val_accuracy=0.9531
# Epoch  90/100: loss=0.0751, accuracy=0.9781, val_loss=0.1014, val_accuracy=0.9699
# Epoch  91/100: loss=0.0734, accuracy=0.9786, val_loss=0.1010, val_accuracy=0.9699
# Epoch  92/100: loss=0.0731, accuracy=0.9790, val_loss=0.1001, val_accuracy=0.9695
# Epoch  93/100: loss=0.0728, accuracy=0.9784, val_loss=0.0996, val_accuracy=0.9707
# Epoch  94/100: loss=0.0713, accuracy=0.9794, val_loss=0.0993, val_accuracy=0.9705
# Epoch  95/100: loss=0.0711, accuracy=0.9788, val_loss=0.0988, val_accuracy=0.9708
# Epoch  96/100: loss=0.0699, accuracy=0.9794, val_loss=0.0982, val_accuracy=0.9709
# Epoch  97/100: loss=0.0696, accuracy=0.9801, val_loss=0.0981, val_accuracy=0.9708
# Epoch  98/100: loss=0.0685, accuracy=0.9804, val_loss=0.0976, val_accuracy=0.9709
# Epoch  99/100: loss=0.0671, accuracy=0.9801, val_loss=0.0967, val_accuracy=0.9716
# Epoch 100/100: loss=0.0671, accuracy=0.9803, val_loss=0.0961, val_accuracy=0.9715

# %%
plot_history(dropout_model_history)
dropout_model_development_results = evaluate_development_sets(
    dropout_model,
    device,
    pin_memory=using_cuda,
    non_blocking=using_cuda,
)
# Out:
# train     : loss=0.0503, accuracy=0.9859
# validation: loss=0.0961, accuracy=0.9715

# %%
dropout_model_path = MODEL_DIR / "mnist_mlp_dropout.pt"
torch.save(dropout_model.state_dict(), dropout_model_path)
print(f"Saved weights to {dropout_model_path}")
# Out:
# Saved weights to /home/gjb/Projects/Machine-learning-with-Python/source-code/pytorch/models/mnist_mlp_dropout.pt

# %% [markdown]
# ## Understanding and selecting the model
#
# The selection rule must be declared before consulting the test set. Here we select the candidate with the lowest validation loss. Accuracy remains useful to report, but loss uses the full predicted distribution and is usually more sensitive when choosing between classifiers.
#
# All diagnostics below use validation data. If a diagnostic motivates another modelling change, retrain and repeat the validation analysis before proceeding to the final test.

# %%
candidate_models = {
    "classic": model,
    "dropout": dropout_model,
}
candidate_results = {
    "classic": model_development_results,
    "dropout": dropout_model_development_results,
}

selected_model_name = min(
    candidate_results,
    key=lambda name: candidate_results[name]["validation"]["loss"],
)
selected_model = candidate_models[selected_model_name]
analysis_model = selected_model

print(
    f"Selected {selected_model_name!r} model: "
    f"validation loss="
    f"{candidate_results[selected_model_name]['validation']['loss']:.4f}"
)
# Out:
# Selected 'dropout' model: validation loss=0.0961

# %% [markdown]
# ### Validation confusion matrix
#
# A confusion matrix reveals which classes the model confuses. Rows represent true labels and columns represent predicted labels. We compute it on the validation set so it can support diagnosis without exposing the test set.

# %%
@torch.inference_mode()
def predict_classes(
    model, data_loader, device, non_blocking=False
):
    model.eval()
    predicted_batches = []
    target_batches = []

    for features, targets in data_loader:
        features = features.to(device, non_blocking=non_blocking)
        logits = model(features)
        predicted_batches.append(logits.argmax(dim=1).cpu())
        target_batches.append(targets)

    return torch.cat(target_batches), torch.cat(predicted_batches)


validation_targets, validation_predictions = predict_classes(
    analysis_model,
    validation_loader,
    device,
    non_blocking=using_cuda,
)

confusion_matrix = torch.bincount(
    10 * validation_targets + validation_predictions,
    minlength=10 * 10,
).reshape(10, 10)

confusion_matrix
# Out:
# tensor([[1516,    0,    2,    0,    0,    3,    7,    1,    5,    2],
#         [   0, 1683,   10,    3,    3,    0,    1,    1,    4,    1],
#         [   8,    3, 1414,    3,    9,    1,    4,    5,    5,    4],
#         [   0,    1,   15, 1509,    1,   16,    1,   12,   10,    6],
#         [   3,    6,    4,    0, 1372,    1,    6,    4,    3,   26],
#         [   4,    2,    2,    9,    3, 1337,   11,    0,    8,    6],
#         [   3,    2,    1,    0,    2,    5, 1432,    0,    1,    0],
#         [   0,    4,    8,    0,    6,    2,    0, 1512,    2,   12],
#         [   1,   16,    5,    8,    7,   10,    9,    4, 1430,    9],
#         [   5,    2,    0,    8,   23,    4,    0,   16,    7, 1368]])

# %%
def plot_confusion_matrix(matrix, normalize=False, cmap="Blues"):
    values = matrix.detach().cpu().numpy().astype(np.float64)

    if normalize:
        row_totals = values.sum(axis=1, keepdims=True)
        display_values = np.divide(
            values,
            row_totals,
            out=np.zeros_like(values),
            where=row_totals != 0,
        )
        color_values = display_values
        value_format = ".3f"
    else:
        display_values = values
        color_values = np.log1p(values)
        value_format = ".0f"

    figure, axes = plt.subplots(figsize=(7, 6))
    image = axes.imshow(color_values, interpolation="nearest", cmap=cmap)
    figure.colorbar(image, ax=axes)

    classes = np.arange(10)
    axes.set(
        xticks=classes,
        yticks=classes,
        xlabel="Predicted label",
        ylabel="True label",
    )

    threshold = color_values.max() / 2.0
    for row in range(10):
        for column in range(10):
            axes.text(
                column,
                row,
                format(display_values[row, column], value_format),
                ha="center",
                va="center",
                color=(
                    "white"
                    if color_values[row, column] > threshold
                    else "black"
                ),
                fontsize=8,
            )

    figure.tight_layout()


plot_confusion_matrix(confusion_matrix, normalize=True)

# %% [markdown]
# Inspect the largest off-diagonal entries. Are the most common confusions visually plausible? A confusion matrix describes error patterns, but it does not by itself explain their cause. Inspect validation images before proposing explanations.
#
# ### Sensitivity to initial conditions
#
# Training is stochastic. To isolate sensitivity to parameter initialization, every repeated run below uses:
#
# - a different model seed;
# - the same train/validation split;
# - the same sequence of shuffled mini-batches.
#
# This controls the data order rather than silently changing initialization and sampling together. The test set is deliberately excluded from this exploratory analysis.

# %%
dataset_loaders = {
    "train": DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=0,
        pin_memory=using_cuda,
    ),
    "validation": validation_loader,
}

losses = {name: [] for name in dataset_loaders}
accuracies = {name: [] for name in dataset_loaders}

for run in range(SENSITIVITY_RUNS):
    run_seed = MODEL_SEED + run
    print(
        f"Training model {run + 1}/{SENSITIVITY_RUNS} "
        f"with seed {run_seed}"
    )

    seed_everything(run_seed)
    repeated_model = make_mlp(dropout_probability=0.2).to(device)
    repeated_optimizer = torch.optim.SGD(
        repeated_model.parameters(), lr=0.01
    )
    repeated_train_loader = make_train_loader(DATA_ORDER_SEED)

    _ = fit(
        model=repeated_model,
        train_loader=repeated_train_loader,
        validation_loader=validation_loader,
        loss_function=loss_function,
        optimizer=repeated_optimizer,
        epochs=SENSITIVITY_EPOCHS,
        device=device,
        non_blocking=using_cuda,
        verbose=False,
    )

    for name, data_loader in dataset_loaders.items():
        metrics = evaluate(
            repeated_model,
            data_loader,
            loss_function,
            device,
            non_blocking=using_cuda,
        )
        losses[name].append(metrics["loss"])
        accuracies[name].append(metrics["accuracy"])
# Out:
# Training model 1/10 with seed 4958
# Training model 4/10 with seed 4961
# Training model 5/10 with seed 4962
# Training model 6/10 with seed 4963
# Training model 7/10 with seed 4964
# Training model 8/10 with seed 4965
# Training model 9/10 with seed 4966
# Training model 10/10 with seed 4967

# %%
def plot_run_variation(losses, accuracies):
    names = list(losses)
    positions = np.arange(len(names))
    jitter = np.linspace(-0.08, 0.08, SENSITIVITY_RUNS)

    figure, axes = plt.subplots(1, 2, figsize=(12, 4))

    for position, name in zip(positions, names):
        axes[0].scatter(
            position + jitter, losses[name], label=name
        )
        axes[1].scatter(
            position + jitter, accuracies[name], label=name
        )

    for axis, ylabel in zip(axes, ["Loss", "Accuracy"]):
        axis.set_xticks(positions, names)
        axis.set_ylabel(ylabel)

    figure.tight_layout()


plot_run_variation(losses, accuracies)

# %%
for name in dataset_loaders:
    loss_values = np.asarray(losses[name])
    accuracy_values = np.asarray(accuracies[name])
    print(
        f"{name:10s}: "
        f"loss={loss_values.mean():.4f} ± {loss_values.std(ddof=0):.4f}, "
        f"accuracy={accuracy_values.mean():.4f} "
        f"± {accuracy_values.std(ddof=0):.4f}"
    )
# Out:
# train     : loss=0.0497 ± 0.0006, accuracy=0.9864 ± 0.0003
# validation: loss=0.0949 ± 0.0009, accuracy=0.9719 ± 0.0006

# %% [markdown]
# ## Interpretation questions
#
# Answer these questions using only the training and validation evidence:
#
# 1. Does dropout reduce the training–validation gap? Does that necessarily mean it is the better model?
# 2. Which digit pairs have the largest off-diagonal validation confusion counts? Inspect several corresponding images before proposing an explanation.
# 3. Is variation across initialization seeds large enough to change your model-selection conclusion?
# 4. Would repeating the experiment with different train/validation splits answer the same scientific question? Why or why not?
# 5. Based on the declared validation-loss criterion, which model was selected? Would selecting by validation accuracy change the choice?
# 6. Which information—software versions, device, seeds, split, transformations, and hyperparameters—would someone need to reproduce the comparison?

# %% [markdown]
# ## Final test evaluation
#
# The model architecture and selection rule are now frozen. Evaluate the selected model on the test set exactly once to estimate its performance on unseen data.
#
# Do not use this result to choose another model or tune another hyperparameter: doing so would turn the test set into another validation set. Further development requires returning to the validation workflow and reserving a fresh test or audit set for a new final evaluation.

# %%
selected_model_path = MODEL_DIR / "mnist_mlp_selected.pt"
torch.save(selected_model.state_dict(), selected_model_path)

final_test_metrics = evaluate(
    selected_model,
    test_loader,
    loss_function,
    device,
    non_blocking=using_cuda,
)

print(f"Selected model: {selected_model_name}")
print(
    f"Final test: loss={final_test_metrics['loss']:.4f}, "
    f"accuracy={final_test_metrics['accuracy']:.4f}"
)
print(f"Saved selected weights to {selected_model_path}")
# Out:
# Selected model: dropout
# Final test: loss=0.0807, accuracy=0.9746
# Saved selected weights to /home/gjb/Projects/Machine-learning-with-Python/source-code/pytorch/models/mnist_mlp_selected.pt
